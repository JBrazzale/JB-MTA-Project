# %%
from sqlalchemy import create_engine
from sqlalchemy import inspect
import pandas as pd

# %%
engine = create_engine("sqlite:///mta_data.db")

# %%
insp = inspect(engine)
print(insp.get_table_names())
#this will allow us to see our table name(s)
# Out:
# ['mta_data']

# %%
full_mta_data = pd.read_sql('SELECT * FROM mta_data;', engine)
full_mta_data 
#This will give us an outline of what our dataframe looks like
# Out:
#            C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0         A002  R051  02-00-00          59 ST  NQR456W      BMT  06/22/2019
# 1         A002  R051  02-00-00          59 ST  NQR456W      BMT  06/22/2019
# 2         A002  R051  02-00-00          59 ST  NQR456W      BMT  06/22/2019
# 3         A002  R051  02-00-00          59 ST  NQR456W      BMT  06/22/2019
# 4         A002  R051  02-00-00          59 ST  NQR456W      BMT  06/22/2019
# ...        ...   ...       ...            ...      ...      ...         ...
# 2664243  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/05/2019
# 2664244  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/05/2019
# 2664245  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/05/2019
# 2664246  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/05/2019
# 2664247  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/05/2019
#
#              TIME     DESC  ENTRIES    EXITS
# ...

# %%
no_of_stations = pd.read_sql('SELECT COUNT(DISTINCT STATION) AS "Number of Stations" FROM mta_data;', engine)
no_of_stations
#quick check to see the number of unique station names
# Out:
#    Number of Stations
# 0                 378

# %%
unique_station_units = pd.read_sql('SELECT STATION, COUNT(DISTINCT UNIT) FROM mta_data GROUP BY STATION ORDER BY COUNT(DISTINCT UNIT) DESC LIMIT 5;', engine)
unique_station_units
#query to see which station has the highest number of unique units
# Out:
#            STATION  COUNT(DISTINCT UNIT)
# 0            23 ST                     6
# 1         CANAL ST                     5
# 2            86 ST                     5
# 3  GRD CNTRL-42 ST                     4
# 4   34 ST-PENN STA                     4
